# %%
# load in image inputs_gs-000000_e-000000_b-000002.png
# load in image reconstruction_gs-000000_e-000000_b-000002.png

PATH = "/Users/szczekulskij/sandbox/ACV/2024-06-02T07-07-14_sd-objaverse-finetune-c_concat-256/images/train/"

input = "inputs_gs-000500_e-000499_b-000004.png"
recon = "reconstruction_gs-000500_e-000499_b-000004.png"

import cv2
import numpy as np
import sys
import matplotlib.pyplot as plt

img1 = cv2.imread(PATH + input)
img2 = cv2.imread(PATH + recon)

# %%
cv2.imshow(img1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 cv2.imshow(img1)
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)

# %%
diff = img1 - img2

# min max diff
_ = plt.hist(diff.flatten(), bins = 256//4)

# %%
plt.imshow(img1 - img2)
